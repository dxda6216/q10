# %% [markdown]
# <a href="https://colab.research.google.com/github/dxda6216/q10/blob/main/circadian_period_q10_bt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ======================================================================
# # Q10 calculator
#
# For usage, see the [GitHub repository page](https://github.com/dxda6216/q10).
#
# This notebook is split into two cells:
# 1. **Helper functions** — the computation and plotting logic (no need to edit this).
# 2. **Inputs & run** — the form where you set your data and options.
#
# Enter your data in the second cell, then use **Runtime → Run all** (or **Ctrl+F9**).
# ======================================================================

#@title Q10 calculator {single-column: true}
#@markdown For usage, see [GitHub repository page](https://github.com/dxda6216/q10).
#@title Helper functions (run this first) { display-mode: "form" }

import numpy as np
import statistics
import pandas as pd
from scipy.optimize import curve_fit
from matplotlib import pyplot as plt


def print_statistics(data_array, name, unit):
    """Print min/max/mean/median for a 1-D array of measurements."""
    min_val = np.min(data_array)
    max_val = np.max(data_array)
    avg_val = statistics.mean(data_array)
    med_val = statistics.median(data_array)
    print(f"Minimum {name} = {min_val:.3f} {unit}")
    print(f"Maximum {name} = {max_val:.3f} {unit}")
    print(f"Average {name} = {avg_val:.3f} {unit}")
    print(f"Median {name}  = {med_val:.3f} {unit}\n")


def select_fit_subset(df, use_range, low_limit, high_limit):
    """Return the subset of df restricted to [low_limit, high_limit], or df unchanged."""
    if not use_range:
        return df
    if low_limit < high_limit:
        return df[(df["Temperature"] >= low_limit) & (df["Temperature"] <= high_limit)]
    return df


def resolve_base_temperature(selection, slider_value, xa):
    """Translate the 'Select_base_temperature' dropdown choice into a numeric value."""
    base_t_mapping = {
        "-273.15\u00B0C (absolute zero)": -273.15,
        "0\u00B0C": 0.000,
        "4\u00B0C": 4.000,
        "25\u00B0C": 25.000,
        "30\u00B0C": 30.000,
        "37\u00B0C": 37.000,
        "100\u00B0C": 100.000,
        "Minimum": np.min(xa),
        "Maximum": np.max(xa),
        "Average": statistics.mean(xa),
        "Median": statistics.median(xa),
        "Set \"Base_temperature\" by slider below": slider_value,
    }
    return base_t_mapping.get(selection, slider_value)


def make_q10_model(base_t):
    """Build f(T) = tau_bt * Q10 ** ((base_t - T) / 10), closed over base_t."""

    def q10_model(temperature, tau_bt, q10):
        return tau_bt * q10 ** ((base_t - temperature) * 0.1)

    return q10_model


def fit_q10(xa, ya, base_t, p0=(24.0, 1.0)):
    """Fit the Q10 model to (xa, ya). Returns (popt, pcov, r_squared, model)."""
    model = make_q10_model(base_t)
    popt, pcov = curve_fit(model, xa, ya, p0=p0)
    residuals = ya - model(xa, *popt)
    ss_residuals = np.sum(residuals ** 2)
    ss_total = np.sum((ya - np.mean(ya)) ** 2)
    r_squared = 1 - (ss_residuals / ss_total)
    return popt, pcov, r_squared, model


def print_tab_delimited_data(x, y, fcx, fcy):
    """Print the raw dataset and the fitted curve as tab-delimited text."""
    print("Dataset")
    print("Temp (\u00B0C)\tPeriod (hours)")
    for xi, yi in zip(x, y):
        print(f"{xi:.3f}\t{yi:.3f}")
    print("\nFitted Curve")
    print("Temp (\u00B0C)\tPeriod (hours)")
    for xi, yi in zip(fcx, fcy):
        print(f"{xi:.3f}\t{yi:.3f}")
    print("\n")


def plot_fit(x, y, xa, ya, fcx, fcy, popt, pcov, base_t, use_range, title):
    """Plot the raw data, the data used for fitting, and the fitted Q10 curve."""
    fig = plt.figure(figsize=(8, 6))

    if not use_range:
        plt.scatter(xa, ya, marker="o", s=35, color="red", label="Data")
    else:
        plt.scatter(x, y, marker="o", s=30, color="lightgreen", label="Data")
        plt.scatter(xa, ya, marker="o", s=35, color="red",
                    label="Data points used for Q10 calculation")

    plt.plot(fcx, fcy, "--", color="blue", label=f"Fit        Q10 = {popt[1]:5.3f}")
    plt.xlabel("Temperature (\u00B0C)")
    plt.ylabel("Period (hours)")

    plt.subplots_adjust(top=0.9, bottom=0.0)
    fig.suptitle(title, fontsize=12)
    fst = (f"Eest. tau at {base_t:.2f} \u00B0C = {popt[0]:.3f} \u00B1 {pcov[0, 0] ** 0.5:.3f} hrs"
           f"      Q10 = {popt[1]:.3f} \u00B1 {pcov[1, 1] ** 0.5:.3f}")
    fig.text(0.5, 0.92, fst, horizontalalignment="center", fontsize=9)
    plt.legend()
    plt.show()


def run_q10_calculator(data_description, temperatures, periods,
                        set_temperature_range, range_low_limit, range_high_limit,
                        select_base_temperature, base_temperature,
                        display_tab_delimited_data):
    """End-to-end pipeline: build the dataframe, fit the Q10 model, print results, plot."""
    x = np.array(temperatures)
    y = np.array(periods)
    df = pd.DataFrame({"Temperature": x, "Period": y})

    print("Input data")
    print(df, "\n")
    print_statistics(x, "temperature", "\u00B0C")
    print_statistics(y, "period", "h")

    use_range = set_temperature_range != "No"
    dfa = select_fit_subset(df, use_range, range_low_limit, range_high_limit)
    xa, ya = dfa["Temperature"], dfa["Period"]

    print("Data used for Q10 calculation")
    print(dfa, "\n")
    print_statistics(xa, "temperature", "\u00B0C")
    print_statistics(ya, "period", "h")

    base_t = resolve_base_temperature(select_base_temperature, base_temperature, xa)
    popt, pcov, r_squared, model = fit_q10(xa, ya, base_t)

    margin = (max(x) - min(x)) * 0.333
    fcx = np.linspace(int(min(x) - margin), int(max(x) + margin) + 1, 200)
    fcy = model(fcx, *popt)

    if display_tab_delimited_data == "Yes":
        print_tab_delimited_data(x, y, fcx, fcy)

    print(f"Estimated period length at {base_t:.2f} \u00B0C = "
          f"{popt[0]:.3f} \u00B1 {pcov[0, 0] ** 0.5:.3f} hours")
    print(f"Q10 (temperature coefficient) = {popt[1]:.3f} \u00B1 {pcov[1, 1] ** 0.5:.3f}")
    print(f"R\u00B2 = {r_squared:.6f}\n")

    plot_fit(x, y, xa, ya, fcx, fcy, popt, pcov, base_t, use_range, data_description)

# ----------------------------------------------------------------------

#@title Q10 calculator — inputs & run {single-column: true}
#@markdown Input data below, then hit **Runtime** -> **Run all** (or press **Ctrl+F9**).

# Data description (plot title)
Data_description = "Mutant ABC" #@param {type:"string"}

# Temperature data
Temperatures = 25.1, 26.9, 27.3, 29.2, 30, 31.7, 32.2, 33.5, 34.1, 35.3, 35.8, 36.5, 37.1, 38.5, 38.9, 39.3, 40.3, 41.1 #@param {type:"raw"}

# Period data
Periods =  33.6, 32.8, 30.4, 29.3, 28.0, 27.9, 26.1, 25.5, 24.9, 24.8, 24.5, 24.4, 24.1, 23.9, 23.6, 21.9, 21.5, 20.1 #@param {type:"raw"}

# Calculation Q10 from the data within a specific temperature range
#@markdown Only data within a specific temperature range to be used for Q10 calculation? (Yes or No)
Set_temperature_range = "No" #@param ["Yes (set lowest and highest limits by sliders below)", "No"]
Range_low_limit = 15 # @param {type:"slider", min:0, max:65, step:0.1}
Range_high_limit = 50 # @param {type:"slider", min:0, max:65, step:0.1}

# Base temperature
#@markdown Setting base temperature
Select_base_temperature = "37°C" #@param ["-273.15\u00B0C (absolute zero)", "0\u00B0C", "4\u00B0C", "25\u00B0C", "30\u00B0C", "37\u00B0C", "100\u00B0C", "Minimum", "Maximum", "Average", "Median", "Set \"Base_temperature\" by slider below"]
Base_temperature = 37 # @param {type:"slider", min:0, max:100, step:0.1}

# Displaying Tab-delimited data Yes or No
#@markdown Displaying tab-delimited data? (Yes or No)
Display_tab_delimited_data = "No" #@param ["Yes", "No"]

run_q10_calculator(
    Data_description, Temperatures, Periods,
    Set_temperature_range, Range_low_limit, Range_high_limit,
    Select_base_temperature, Base_temperature,
    Display_tab_delimited_data,
)

# ----------------------------------------------------------------------
